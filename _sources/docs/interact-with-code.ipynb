# %% [markdown]
# # Interact with code
#
# When a certain page is written inside a Jupyter Notebook (.ipynb), you will automatically see a rocket in the top corner to launch the page you are on into a custom interactive environment. There, you can have all the capabilites of JupyterLab and the extensions the AICoE offers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = 2
x + 5
# Out:
# 7

# %% [markdown]
# ```{tip}
# However, if you want users to focus on the prose, you can also hide code (or ouptput).
# ```

# %%
# hidden block

x = np.linspace(0, 10, 200)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y, 'b-', linewidth=2)
